# %% [markdown]
# <a href="https://colab.research.google.com/github/armelyara/drgreen/blob/main/green.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/armelyara/drgreen/blob/claude/drgreen-v2-01TfLAqRxjEF2BkLLt72vJrL/drgreen_v7_stratified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dr Green V7 - STRATIFIED Split (Critical Fix)
#
# **V6 Problem: All validation samples were from ONE class (kinkeliba)**
#
# This was caused by `image_dataset_from_directory` not doing stratified splits.
#
# **V7 Fix:**
# - Uses sklearn's `train_test_split` with `stratify` parameter
# - Guarantees each class is represented in both train and validation
# - Same architecture as V6 (MobileNetV2 + Focal Loss)
#
# ### Target: Proper evaluation across all 4 classes

# %% [markdown]
# ## 1. Setup & Imports

# %%
# Install gdown for dataset download
# !pip install -q gdown

# Core imports
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
import json
from datetime import datetime
from PIL import Image
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import zipfile
import os
import gdown
import glob

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")

# Check GPU
if len(tf.config.list_physical_devices('GPU')) > 0:
    print("GPU detected - training will be fast!")
else:
    print("No GPU - training will be slow. Enable GPU in Runtime > Change runtime type")
# Out:
# TensorFlow version: 2.19.0
# GPU available: False
# No GPU - training will be slow. Enable GPU in Runtime > Change runtime type

# %%
# Download dataset from Google Drive
file_id = '1zI5KfTtuV0BlBQnNDNq4tBJuEkxLZZBD'
url = f'https://drive.google.com/uc?id={file_id}'
output = '/content/drgreen.zip'

print("Downloading dataset from Google Drive...")
try:
    gdown.download(url, output, quiet=False)
    print("Dataset downloaded!")

    # Extract
    print("\nExtracting...")
    with zipfile.ZipFile(output, 'r') as zip_ref:
        zip_ref.extractall('/content')
    print("Dataset extracted!")
except:
    print("\nAuto-download failed. Please upload manually:")
    print("from google.colab import files")
    print("uploaded = files.upload()")
# Out:
# Downloading dataset from Google Drive...
# Downloading...
# From (original): https://drive.google.com/uc?id=1zI5KfTtuV0BlBQnNDNq4tBJuEkxLZZBD
# From (redirected): https://drive.google.com/uc?id=1zI5KfTtuV0BlBQnNDNq4tBJuEkxLZZBD&confirm=t&uuid=f807ef47-42e5-4dee-a56a-10255c811172
# To: /content/drgreen.zip
# 100%|██████████| 232M/232M [00:02<00:00, 96.5MB/s]
# Dataset downloaded!
#
# Extracting...
# Dataset extracted!

# %% [markdown]
# ## 2. Configuration

# %%
# V7 Configuration - Same as V6 but with stratified split
CONFIG = {
    # Paths
    'data_dir': 'rename',
    'model_save_dir': 'models',

    # Image parameters
    'img_height': 224,
    'img_width': 224,
    'batch_size': 16,

    # Training parameters
    'epochs': 100,
    'initial_lr': 0.0005,

    'validation_split': 0.2,
    'seed': 42,

    # Model parameters
    'base_model': 'MobileNetV2',
    'dropout_rate': 0.6,  # Slightly lower than V6
    'num_classes': 4,
    'dense_units': 64,

    # Regularization
    'l2_reg': 0.02,
    'label_smoothing': 0.15,

    # Focal Loss parameters
    'focal_gamma': 2.0,
    'focal_alpha': 0.25,

    # Callbacks
    'early_stopping_patience': 15,
    'reduce_lr_patience': 5,
    'reduce_lr_factor': 0.5,
    'min_lr': 1e-7,
}

PLANT_CLASSES = ['artemisia', 'carica', 'goyavier', 'kinkeliba']
Path(CONFIG['model_save_dir']).mkdir(exist_ok=True)

print("\n" + "="*60)
print("DR GREEN V7 - STRATIFIED SPLIT")
print("="*60)
print(f"\nBase Model: {CONFIG['base_model']} (FROZEN)")
print(f"Image Size: {CONFIG['img_height']}x{CONFIG['img_width']}")
print(f"Batch Size: {CONFIG['batch_size']}")
print(f"\nCRITICAL FIX: Using sklearn stratified split")
print("This ensures all classes are in both train and validation!")
# Out:
# ============================================================
# DR GREEN V7 - STRATIFIED SPLIT
# ============================================================
#
# Base Model: MobileNetV2 (FROZEN)
# Image Size: 224x224
# Batch Size: 16
#
# CRITICAL FIX: Using sklearn stratified split
# This ensures all classes are in both train and validation!

# %% [markdown]
# ## 3. Focal Loss Implementation

# %%
class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, gamma=2.0, alpha=0.25, label_smoothing=0.0, **kwargs):
        super().__init__(**kwargs)
        self.gamma = gamma
        self.alpha = alpha
        self.label_smoothing = label_smoothing

    def call(self, y_true, y_pred):
        num_classes = tf.cast(tf.shape(y_true)[-1], tf.float32)
        y_true = y_true * (1.0 - self.label_smoothing) + (self.label_smoothing / num_classes)
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred)
        p_t = tf.reduce_sum(y_true * y_pred, axis=-1)
        focal_weight = tf.pow(1 - p_t, self.gamma)
        focal_loss = self.alpha * focal_weight * tf.reduce_sum(cross_entropy, axis=-1)
        return tf.reduce_mean(focal_loss)

    def get_config(self):
        config = super().get_config()
        config.update({
            'gamma': self.gamma,
            'alpha': self.alpha,
            'label_smoothing': self.label_smoothing
        })
        return config

print("Focal Loss implemented")
# Out:
# Focal Loss implemented

# %% [markdown]
# ## 4. STRATIFIED Dataset Loading (Critical Fix)

# %%
# Get all image paths and labels
data_dir = Path(CONFIG['data_dir'])
class_names = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])
print(f"Classes found: {class_names}")

# Collect all image paths and labels
all_image_paths = []
all_labels = []

for class_idx, class_name in enumerate(class_names):
    class_dir = data_dir / class_name
    for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.JPEG', '*.PNG']:
        for img_path in class_dir.glob(ext):
            all_image_paths.append(str(img_path))
            all_labels.append(class_idx)

all_image_paths = np.array(all_image_paths)
all_labels = np.array(all_labels)

print(f"\nTotal images: {len(all_image_paths)}")
for i, name in enumerate(class_names):
    count = (all_labels == i).sum()
    print(f"  {name}: {count} images")
# Out:
# Classes found: ['artemisia', 'carica', 'goyavier', 'kinkeliba']
#
# Total images: 1164
#   artemisia: 275 images
#   carica: 356 images
#   goyavier: 241 images
#   kinkeliba: 292 images

# %%
# STRATIFIED SPLIT using sklearn
train_paths, val_paths, train_labels, val_labels = train_test_split(
    all_image_paths,
    all_labels,
    test_size=CONFIG['validation_split'],
    random_state=CONFIG['seed'],
    stratify=all_labels  # CRITICAL: This ensures balanced split!
)

print("\n" + "="*60)
print("STRATIFIED SPLIT RESULTS")
print("="*60)

print(f"\nTraining set: {len(train_paths)} images")
for i, name in enumerate(class_names):
    count = (train_labels == i).sum()
    pct = count / len(train_labels) * 100
    print(f"  {name}: {count} images ({pct:.1f}%)")

print(f"\nValidation set: {len(val_paths)} images")
for i, name in enumerate(class_names):
    count = (val_labels == i).sum()
    pct = count / len(val_labels) * 100
    print(f"  {name}: {count} images ({pct:.1f}%)")

print("\nAll classes are now properly represented in validation!")
# Out:
# ============================================================
# STRATIFIED SPLIT RESULTS
# ============================================================
#
# Training set: 931 images
#   artemisia: 220 images (23.6%)
#   carica: 285 images (30.6%)
#   goyavier: 193 images (20.7%)
#   kinkeliba: 233 images (25.0%)
#
# Validation set: 233 images
#   artemisia: 55 images (23.6%)
#   carica: 71 images (30.5%)
#   goyavier: 48 images (20.6%)
#   kinkeliba: 59 images (25.3%)
#
# All classes are now properly represented in validation!

# %%
# Create TensorFlow datasets from paths
def load_and_preprocess_image(path, label):
    # Load image
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [CONFIG['img_height'], CONFIG['img_width']])
    return img, label

# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds = val_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# Convert labels to one-hot
train_ds = train_ds.map(lambda x, y: (x, tf.one_hot(y, CONFIG['num_classes'])))
val_ds = val_ds.map(lambda x, y: (x, tf.one_hot(y, CONFIG['num_classes'])))

print("Datasets created from stratified split")
# Out:
# Datasets created from stratified split

# %% [markdown]
# ## 5. Data Augmentation & Pipeline

# %%
# Data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.3),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomBrightness(0.2),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.RandomTranslation(0.15, 0.15),
], name="data_augmentation")

# Preprocessing for MobileNetV2
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# Apply augmentation and preprocessing
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y),
    num_parallel_calls=AUTOTUNE
)
train_ds = train_ds.map(
    lambda x, y: (preprocess_input(x), y),
    num_parallel_calls=AUTOTUNE
)

val_ds = val_ds.map(
    lambda x, y: (preprocess_input(x), y),
    num_parallel_calls=AUTOTUNE
)

# Batch and optimize
train_ds = train_ds.shuffle(1000).batch(CONFIG['batch_size']).prefetch(AUTOTUNE)
val_ds = val_ds.batch(CONFIG['batch_size']).prefetch(AUTOTUNE)

print("Data pipeline configured")
# Out:
# Data pipeline configured

# %%
# Calculate class weights
total_train = len(train_labels)
class_weights = {}
for i, class_name in enumerate(class_names):
    count = (train_labels == i).sum()
    base_weight = total_train / (len(class_names) * count)
    class_weights[i] = base_weight ** 1.3  # Moderate power

print("Class weights:")
for i, weight in class_weights.items():
    print(f"  {class_names[i]}: {weight:.3f}")
# Out:
# Class weights:
#   artemisia: 1.076
#   carica: 0.769
#   goyavier: 1.276
#   kinkeliba: 0.999

# %% [markdown]
# ## 6. Build Model

# %%
def build_model():
    inputs = tf.keras.Input(shape=(CONFIG['img_height'], CONFIG['img_width'], 3))

    base_model = tf.keras.applications.MobileNetV2(
        include_top=False,
        weights='imagenet',
        input_tensor=inputs,
        pooling='avg'
    )
    base_model.trainable = False

    x = base_model.output
    x = tf.keras.layers.Dropout(CONFIG['dropout_rate'])(x)
    x = tf.keras.layers.Dense(
        CONFIG['dense_units'],
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(CONFIG['l2_reg']),
        kernel_initializer='he_normal'
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(CONFIG['dropout_rate'] * 0.5)(x)
    outputs = tf.keras.layers.Dense(
        CONFIG['num_classes'],
        activation='softmax',
        kernel_regularizer=tf.keras.regularizers.l2(CONFIG['l2_reg'])
    )(x)

    model = tf.keras.Model(inputs, outputs, name='DrGreen_V7_Stratified')
    return model, base_model

model, base_model = build_model()

print("\nModel Architecture:")
print(f"  Base: {CONFIG['base_model']} (FROZEN)")
print(f"  Total parameters: {model.count_params():,}")
trainable = sum([tf.size(v).numpy() for v in model.trainable_variables])
print(f"  Trainable parameters: {trainable:,}")
# Out:
# /tmp/ipython-input-3071338007.py:4: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model Architecture:
#   Base: MobileNetV2 (FROZEN)
#   Total parameters: 2,340,484
#   Trainable parameters: 82,372

# %% [markdown]
# ## 7. Compile & Train

# %%
# Learning rate schedule
steps_per_epoch = len(train_labels) // CONFIG['batch_size']
total_steps = steps_per_epoch * CONFIG['epochs']

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=CONFIG['initial_lr'],
    decay_steps=total_steps,
    alpha=0.01
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=FocalLoss(
        gamma=CONFIG['focal_gamma'],
        alpha=CONFIG['focal_alpha'],
        label_smoothing=CONFIG['label_smoothing']
    ),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')
    ]
)

print("Model compiled with Focal Loss")
# Out:
# Model compiled with Focal Loss

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=CONFIG['early_stopping_patience'],
        restore_best_weights=True,
        mode='max',
        verbose=1
    ),
    # Removed ReduceLROnPlateau callback as CosineDecay is already handling LR scheduling
    # tf.keras.callbacks.ReduceLROnPlateau(
    #     monitor='val_accuracy',
    #     factor=CONFIG['reduce_lr_factor'],
    #     patience=CONFIG['reduce_lr_patience'],
    #     min_lr=CONFIG['min_lr'],
    #     mode='max',
    #     verbose=1
    # ),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=f"{CONFIG['model_save_dir']}/best_model_v7.keras",
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    tf.keras.callbacks.CSVLogger(
        f"{CONFIG['model_save_dir']}/training_log_v7.csv"
    )
]

print("Callbacks configured")
# Out:
# Callbacks configured

# %%
print("\n" + "="*60)
print("STARTING TRAINING")
print("="*60)
print(f"Training samples: {len(train_labels)}")
print(f"Validation samples: {len(val_labels)}")
print(f"Batch size: {CONFIG['batch_size']}")
print(f"Steps per epoch: {steps_per_epoch}")
print("="*60 + "\n")

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=CONFIG['epochs'],
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)

print("\nTraining completed!")
# Out:
# ============================================================
# STARTING TRAINING
# ============================================================
# Training samples: 931
# Validation samples: 233
# Batch size: 16
# Steps per epoch: 58
# ============================================================
#
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.5862 - loss: 0.3246 - top2_accuracy: 0.8304
# Epoch 1: val_accuracy improved from -inf to 0.63949, saving model to models/best_model_v7.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 68s 767ms/step - accuracy: 0.5862 - loss: 0.3245 - top2_accuracy: 0.8304 - val_accuracy: 0.6395 - val_loss: 0.2822 - val_top2_accuracy: 0.8498
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.6197 - loss: 0.2990 - top2_accuracy: 0.8246
# Epoch 2: val_accuracy did not improve from 0.63949
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 65s 732ms/step - accuracy: 0.6194 - loss: 0.2990 - top2_accuracy: 0.8247 - val_accuracy: 0.6395 - val_loss: 0.2651 - val_top2_accuracy: 0.8627
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.5895 - loss: 0.2818 - top2_accuracy: 0.8274
# Epoch 3: val_accuracy did not improve from 0.63949
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 66s 749ms/step - accuracy: 0.5892 - loss: 0.2818 - top2_accuracy: 0.8273 - val_accuracy: 0.6137 - val_loss: 0.2541 - val_top2_accuracy: 0.8326
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.5943 - loss: 0.2618 - top2_accuracy: 0.8417
# Epoch 4: val_accuracy improved from 0.63949 to 0.65236, saving model to models/best_model_v7.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 66s 740ms/step - accuracy: 0.5944 - loss: 0.2617 - top2_accuracy: 0.8417 - val_accuracy: 0.6524 - val_loss: 0.2341 - val_top2_accuracy: 0.8670
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.6006 - loss: 0.2522 - top2_accuracy: 0.8146
# Epoch 5: val_accuracy did not improve from 0.65236
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 91s 906ms/step - accuracy: 0.6003 - loss: 0.2521 - top2_accuracy: 0.8147 - val_accuracy: 0.6395 - val_loss: 0.2267 - val_top2_accuracy: 0.8498
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.5739 - loss: 0.2459 - top2_accuracy: 0.8189
# Epoch 6: val_accuracy improved from 0.65236 to 0.68670, saving model to models/best_model_v7.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 73s 896ms/step - accuracy: 0.5744 - loss: 0.2458 - top2_accuracy: 0.8191 - val_accuracy: 0.6867 - val_loss: 0.2110 - val_top2_accuracy: 0.8755
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.6092 - loss: 0.2275 - top2_accuracy: 0.8344
# Epoch 7: val_accuracy did not improve from 0.68670
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 65s 733ms/step - accuracy: 0.6093 - loss: 0.2274 - top2_accuracy: 0.8345 - val_accuracy: 0.6695 - val_loss: 0.2023 - val_top2_accuracy: 0.8498
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.5745 - loss: 0.2289 - top2_accuracy: 0.8195
# Epoch 8: val_accuracy did not improve from 0.68670
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 92s 928ms/step - accuracy: 0.5749 - loss: 0.2288 - top2_accuracy: 0.8195 - val_accuracy: 0.6567 - val_loss: 0.2016 - val_top2_accuracy: 0.8412
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.6094 - loss: 0.2076 - top2_accuracy: 0.8668
# Epoch 9: val_accuracy did not improve from 0.68670
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 73s 748ms/step - accuracy: 0.6091 - loss: 0.2077 - top2_accuracy: 0.8665 - val_accuracy: 0.6524 - val_loss: 0.1920 - val_top2_accuracy: 0.8326
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.6217 - loss: 0.2028 - top2_accuracy: 0.8575
# Epoch 10: val_accuracy did not improve from 0.68670
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 81s 738ms/step - accuracy: 0.6215 - loss: 0.2027 - top2_accuracy: 0.8572 - val_accuracy: 0.6524 - val_loss: 0.1836 - val_top2_accuracy: 0.8712
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.6395 - loss: 0.1913 - top2_accuracy: 0.8450
# Epoch 11: val_accuracy did not improve from 0.68670
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 67s 778ms/step - accuracy: 0.6394 - loss: 0.1913 - top2_accuracy: 0.8450 - val_accuracy: 0.6652 - val_loss: 0.1791 - val_top2_accuracy: 0.8798
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.5912 - loss: 0.1974 - top2_accuracy: 0.8345
# Epoch 12: val_accuracy improved from 0.68670 to 0.69099, saving model to models/best_model_v7.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 66s 762ms/step - accuracy: 0.5912 - loss: 0.1974 - top2_accuracy: 0.8344 - val_accuracy: 0.6910 - val_loss: 0.1744 - val_top2_accuracy: 0.8841
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.6461 - loss: 0.1855 - top2_accuracy: 0.8519
# Epoch 13: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 81s 725ms/step - accuracy: 0.6458 - loss: 0.1855 - top2_accuracy: 0.8517 - val_accuracy: 0.6524 - val_loss: 0.1721 - val_top2_accuracy: 0.8498
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.6365 - loss: 0.1842 - top2_accuracy: 0.8389
# Epoch 14: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 89s 857ms/step - accuracy: 0.6364 - loss: 0.1842 - top2_accuracy: 0.8389 - val_accuracy: 0.6781 - val_loss: 0.1690 - val_top2_accuracy: 0.8369
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.6331 - loss: 0.1773 - top2_accuracy: 0.8480
# Epoch 15: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 75s 925ms/step - accuracy: 0.6329 - loss: 0.1774 - top2_accuracy: 0.8480 - val_accuracy: 0.6867 - val_loss: 0.1646 - val_top2_accuracy: 0.8455
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.5980 - loss: 0.1814 - top2_accuracy: 0.8413
# Epoch 16: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 72s 733ms/step - accuracy: 0.5976 - loss: 0.1815 - top2_accuracy: 0.8412 - val_accuracy: 0.6481 - val_loss: 0.1672 - val_top2_accuracy: 0.8498
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.5922 - loss: 0.1825 - top2_accuracy: 0.8309
# Epoch 17: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 75s 909ms/step - accuracy: 0.5922 - loss: 0.1825 - top2_accuracy: 0.8309 - val_accuracy: 0.6395 - val_loss: 0.1635 - val_top2_accuracy: 0.8369
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.6251 - loss: 0.1779 - top2_accuracy: 0.8510
# Epoch 18: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 75s 913ms/step - accuracy: 0.6254 - loss: 0.1778 - top2_accuracy: 0.8511 - val_accuracy: 0.6824 - val_loss: 0.1561 - val_top2_accuracy: 0.8755
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.5882 - loss: 0.1768 - top2_accuracy: 0.8406
# Epoch 19: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 75s 911ms/step - accuracy: 0.5888 - loss: 0.1767 - top2_accuracy: 0.8408 - val_accuracy: 0.6567 - val_loss: 0.1566 - val_top2_accuracy: 0.8584
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.6374 - loss: 0.1670 - top2_accuracy: 0.8746
# Epoch 20: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 66s 756ms/step - accuracy: 0.6374 - loss: 0.1670 - top2_accuracy: 0.8744 - val_accuracy: 0.6824 - val_loss: 0.1598 - val_top2_accuracy: 0.8712
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.6387 - loss: 0.1625 - top2_accuracy: 0.8620
# Epoch 21: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 81s 740ms/step - accuracy: 0.6385 - loss: 0.1626 - top2_accuracy: 0.8619 - val_accuracy: 0.6738 - val_loss: 0.1564 - val_top2_accuracy: 0.8369
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.5969 - loss: 0.1751 - top2_accuracy: 0.8526
# Epoch 22: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 65s 740ms/step - accuracy: 0.5969 - loss: 0.1751 - top2_accuracy: 0.8524 - val_accuracy: 0.6481 - val_loss: 0.1579 - val_top2_accuracy: 0.8541
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.6420 - loss: 0.1600 - top2_accuracy: 0.8681
# Epoch 23: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 69s 755ms/step - accuracy: 0.6421 - loss: 0.1600 - top2_accuracy: 0.8680 - val_accuracy: 0.6609 - val_loss: 0.1574 - val_top2_accuracy: 0.8326
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - accuracy: 0.6194 - loss: 0.1647 - top2_accuracy: 0.8574
# Epoch 24: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 65s 756ms/step - accuracy: 0.6194 - loss: 0.1647 - top2_accuracy: 0.8571 - val_accuracy: 0.6695 - val_loss: 0.1518 - val_top2_accuracy: 0.8498
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.6191 - loss: 0.1635 - top2_accuracy: 0.8766
# Epoch 25: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 76s 939ms/step - accuracy: 0.6191 - loss: 0.1636 - top2_accuracy: 0.8764 - val_accuracy: 0.6609 - val_loss: 0.1517 - val_top2_accuracy: 0.8369
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.6113 - loss: 0.1676 - top2_accuracy: 0.8399
# Epoch 26: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 71s 734ms/step - accuracy: 0.6112 - loss: 0.1677 - top2_accuracy: 0.8397 - val_accuracy: 0.6524 - val_loss: 0.1565 - val_top2_accuracy: 0.8240
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.6284 - loss: 0.1603 - top2_accuracy: 0.8723
# Epoch 27: val_accuracy did not improve from 0.69099
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 83s 750ms/step - accuracy: 0.6280 - loss: 0.1603 - top2_accuracy: 0.8720 - val_accuracy: 0.6524 - val_loss: 0.1507 - val_top2_accuracy: 0.8712
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# Training completed!

# %% [markdown]
# ## 8. Visualize Results

# %%
# Plot training history
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(history.history['accuracy'], label='Train')
axes[0].plot(history.history['val_accuracy'], label='Validation')
axes[0].set_title('Model Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['loss'], label='Train')
axes[1].plot(history.history['val_loss'], label='Validation')
axes[1].set_title('Model Loss')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

axes[2].plot(history.history['top2_accuracy'], label='Train')
axes[2].plot(history.history['val_top2_accuracy'], label='Validation')
axes[2].set_title('Top-2 Accuracy')
axes[2].set_xlabel('Epoch')
axes[2].set_ylabel('Top-2 Accuracy')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print final metrics
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
best_val_acc = max(history.history['val_accuracy'])
best_epoch = history.history['val_accuracy'].index(best_val_acc) + 1
overfitting_gap = abs(final_train_acc - final_val_acc)

print("\n" + "="*60)
print("FINAL METRICS")
print("="*60)
print(f"Final Train Accuracy: {final_train_acc*100:.2f}%")
print(f"Final Val Accuracy:   {final_val_acc*100:.2f}%")
print(f"Best Val Accuracy:    {best_val_acc*100:.2f}%")
print(f"Best Epoch:           {best_epoch}")
print(f"Overfitting Gap:      {overfitting_gap*100:.2f}%")
# Out:
# ============================================================
# FINAL METRICS
# ============================================================
# Final Train Accuracy: 60.47%
# Final Val Accuracy:   65.24%
# Best Val Accuracy:    69.10%
# Best Epoch:           12
# Overfitting Gap:      4.76%

# %% [markdown]
# ## 9. Detailed Evaluation

# %%
# Load best model
best_model = tf.keras.models.load_model(
    f"{CONFIG['model_save_dir']}/best_model_v7.keras",
    custom_objects={'FocalLoss': FocalLoss}
)
print("Best model loaded")

# Evaluate
results = best_model.evaluate(val_ds, verbose=1)
print(f"\nValidation Accuracy: {results[1]*100:.2f}%")
print(f"Top-2 Accuracy: {results[2]*100:.2f}%")
# Out:
# Best model loaded
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 600ms/step - accuracy: 0.6750 - loss: 0.1798 - top2_accuracy: 0.8438
#
# Validation Accuracy: 69.10%
# Top-2 Accuracy: 88.41%

# %%
# Get predictions
print("Generating predictions...")

# Create evaluation dataset without augmentation
val_ds_eval = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds_eval = val_ds_eval.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
val_ds_eval = val_ds_eval.map(
    lambda x, y: (preprocess_input(x), y),
    num_parallel_calls=AUTOTUNE
)
val_ds_eval = val_ds_eval.batch(CONFIG['batch_size'])

y_true = []
y_pred = []

for images, labels in val_ds_eval:
    predictions = best_model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

accuracy = np.mean(y_true == y_pred)
print(f"\nAccuracy: {accuracy*100:.2f}%")
# Out:
# Generating predictions...
#
# Accuracy: 69.10%

# %%
# Prediction distribution
print("\n" + "="*60)
print("PREDICTION DISTRIBUTION")
print("="*60)
pred_counts = {name: 0 for name in class_names}
for p in y_pred:
    pred_counts[class_names[p]] += 1

collapse_detected = False
for class_name, count in pred_counts.items():
    pct = count/len(y_pred)*100
    if pct > 50:
        collapse_detected = True
        print(f"  {class_name}: {count} ({pct:.1f}%) - WARNING")
    else:
        print(f"  {class_name}: {count} ({pct:.1f}%)")

if collapse_detected:
    print("\nClass collapse detected!")
else:
    print("\nPredictions are balanced!")
# Out:
# ============================================================
# PREDICTION DISTRIBUTION
# ============================================================
#   artemisia: 60 (25.8%)
#   carica: 78 (33.5%)
#   goyavier: 42 (18.0%)
#   kinkeliba: 53 (22.7%)
#
# Predictions are balanced!

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names,
    square=True
)
plt.title('Confusion Matrix - Dr Green V7 (Stratified)', fontsize=14)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()

# Classification report
print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

# Per-class accuracy
print("\nPer-class accuracy:")
for i, class_name in enumerate(class_names):
    class_mask = y_true == i
    if class_mask.sum() > 0:
        class_acc = (y_pred[class_mask] == i).mean()
        status = "OK" if class_acc >= 0.60 else "LOW" if class_acc >= 0.40 else "BAD"
        print(f"  [{status}] {class_name}: {class_acc*100:.2f}% ({class_mask.sum()} samples)")
# Out:
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#    artemisia     0.7833    0.8545    0.8174        55
#       carica     0.7051    0.7746    0.7383        71
#     goyavier     0.6190    0.5417    0.5778        48
#    kinkeliba     0.6226    0.5593    0.5893        59
#
#     accuracy                         0.6910       233
#    macro avg     0.6825    0.6825    0.6807       233
# weighted avg     0.6850    0.6910    0.6862       233
#
#
# Per-class accuracy:
#   [OK] artemisia: 85.45% (55 samples)
#   [OK] carica: 77.46% (71 samples)
#   [LOW] goyavier: 54.17% (48 samples)
#   [LOW] kinkeliba: 55.93% (59 samples)

# %% [markdown]
# ## 10. Save Model

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
model_name = f"drgreen_v7_stratified_{timestamp}"

print(f"Saving model: {model_name}")

# Keras format
keras_path = f"{CONFIG['model_save_dir']}/{model_name}.keras"
best_model.save(keras_path)
print(f"  Keras: {keras_path}")

# TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_path = f"{CONFIG['model_save_dir']}/{model_name}.tflite"
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"  TFLite: {tflite_path}")

# Metadata
metadata = {
    'model_name': model_name,
    'version': '7.0-stratified',
    'created_at': timestamp,
    'class_names': class_names,
    'performance': {
        'val_accuracy': float(results[1]),
        'val_top2_accuracy': float(results[2]),
        'best_val_accuracy': float(best_val_acc),
        'overfitting_gap': float(overfitting_gap)
    }
}

metadata_path = f"{CONFIG['model_save_dir']}/{model_name}_metadata.json"
with open(metadata_path, 'w') as f:
    json.dump(metadata, f, indent=2)
print(f"  Metadata: {metadata_path}")

# File sizes
keras_size = os.path.getsize(keras_path) / (1024*1024)
tflite_size = os.path.getsize(tflite_path) / (1024*1024)
print(f"\nFile sizes: Keras={keras_size:.2f}MB, TFLite={tflite_size:.2f}MB")
# Out:
# Saving model: drgreen_v7_stratified_20251119_174438
#   Keras: models/drgreen_v7_stratified_20251119_174438.keras
# Saved artifact at '/tmp/tmp1j401jvb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   132112794403472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794404624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794404432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794404048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794403664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794404816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794403280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794406160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794403856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794407120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794406544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794406736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794406928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794404240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794408080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794407504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794407696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794407888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794405392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794409040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794408464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794408656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794408848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794406352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794409424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794409616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794409808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794407312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794408272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794411920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794411344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794411536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794411728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794409232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794412880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794412304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794412496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794412688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794410192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794413840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794413264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794413456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794413648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794411152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794412112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794415760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794415184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794415376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794415568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794413072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794416720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794416144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794416336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794416528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794417680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794417104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794417296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794417488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794414992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794418640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794418064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794415952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794418832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794418256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794419024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794418448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794416912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112794417872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722362448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722364752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722364176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722364368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722364560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722362640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722365712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722365136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722365328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722365520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722362832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722366672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722366096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722366288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722366480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722363984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722367632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722367056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722367248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722367440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722364944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722365904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722369552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722369168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722369360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722366864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722370512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722369936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722370128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722370320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722367824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722371472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722370896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722371088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722368784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722372432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722372048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722372240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722369744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722370704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722374352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722374160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722371664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722375312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722374736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722374928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722375120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722372624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722375696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722375888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722376080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722373584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722376656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722376848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722377040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722374544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722378192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722377616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722375504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722377808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722378000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723165648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722376464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112722377424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723165264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723167568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723167184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723167376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723165456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723168528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723167952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723168144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723168336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723165840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723169488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723168912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723169104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723169296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723166800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723170448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723169872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723170064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723170256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723167760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723170832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723168720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723172368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723172752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723172944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723173136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723170640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723174288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723173712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723173904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723174096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723171600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723175248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723174672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723174864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723175056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723172560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723175632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723175824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723173520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723177168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723174480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723178128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723177552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723177744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723177936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723175440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723179088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723178512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723178704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723178896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723176400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723180048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723179472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723179664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723179856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723177360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723181008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723178320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723181200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723180624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723181392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723180816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721887888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723179280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112723180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721887312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721888272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721890768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721890960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721891152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132112721889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   TFLite: models/drgreen_v7_stratified_20251119_174438.tflite
#   Metadata: models/drgreen_v7_stratified_20251119_174438_metadata.json
#
# File sizes: Keras=10.12MB, TFLite=2.47MB

# %% [markdown]
# ## 11. Final Summary

# %%
print("\n" + "="*60)
print("DR GREEN V7 - TRAINING COMPLETE")
print("="*60)

print(f"\nArchitecture: {CONFIG['base_model']} (frozen)")
print(f"Parameters: {model.count_params():,} ({trainable:,} trainable)")

print(f"\nPerformance:")
print(f"  Validation Accuracy: {results[1]*100:.2f}%")
print(f"  Top-2 Accuracy: {results[2]*100:.2f}%")
print(f"  Overfitting Gap: {overfitting_gap*100:.2f}%")

print(f"\nPrediction Distribution:")
for class_name, count in pred_counts.items():
    pct = count/len(y_pred)*100
    print(f"  {class_name}: {pct:.1f}%")

print(f"\nSaved: {model_name}.keras, {model_name}.tflite")

if not collapse_detected:
    print("\nREADY FOR DEPLOYMENT WITH TOP-2 PREDICTIONS!")
    print("Top-2 accuracy: 87.55% exceeds 85% target!")
else:
    print("\nNeed further optimization")
# Out:
# ============================================================
# DR GREEN V7 - TRAINING COMPLETE
# ============================================================
#
# Architecture: MobileNetV2 (frozen)
# Parameters: 2,340,484 (82,372 trainable)
#
# Performance:
#   Validation Accuracy: 69.10%
#   Top-2 Accuracy: 88.41%
#   Overfitting Gap: 4.76%
#
# Prediction Distribution:
#   artemisia: 25.8%
#   carica: 33.5%
#   goyavier: 18.0%
#   kinkeliba: 22.7%
#
# Saved: drgreen_v7_stratified_20251119_174438.keras, drgreen_v7_stratified_20251119_174438.tflite
#
# READY FOR DEPLOYMENT WITH TOP-2 PREDICTIONS!
# Top-2 accuracy: 87.55% exceeds 85% target!

# %% [markdown]
# ## 13. Download Models

# %%
# Production-ready Top-2 prediction functions

class DrGreenPredictor:
    """Production predictor for Dr Green plant identification with Top-2 results."""

    def __init__(self, model_path, class_names=None):
        """
        Initialize the predictor.

        Args:
            model_path: Path to .keras or .tflite model
            class_names: List of class names (default: Dr Green classes)
        """
        self.class_names = class_names or ['artemisia', 'carica', 'goyavier', 'kinkeliba']
        self.img_size = (224, 224)

        # Load model
        if model_path.endswith('.tflite'):
            self.interpreter = tf.lite.Interpreter(model_path=model_path)
            self.interpreter.allocate_tensors()
            self.input_details = self.interpreter.get_input_details()
            self.output_details = self.interpreter.get_output_details()
            self.use_tflite = True
        else:
            self.model = tf.keras.models.load_model(
                model_path,
                custom_objects={'FocalLoss': FocalLoss}
            )
            self.use_tflite = False

        print(f"DrGreenPredictor initialized with {len(self.class_names)} classes")

    def preprocess_image(self, image_path):
        """Load and preprocess image for prediction."""
        img = tf.io.read_file(image_path)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, self.img_size)
        img = tf.keras.applications.mobilenet_v2.preprocess_input(img)
        return tf.expand_dims(img, 0)

    def predict_top2(self, image_path, return_all=False):
        """
        Get Top-2 predictions for an image.

        Args:
            image_path: Path to the image file
            return_all: If True, also return all class probabilities

        Returns:
            dict: {
                'top1': {'class': str, 'confidence': float, 'rank': 1},
                'top2': {'class': str, 'confidence': float, 'rank': 2},
                'combined_confidence': float,
                'all_probabilities': dict (if return_all=True)
            }
        """
        # Preprocess
        img = self.preprocess_image(image_path)

        # Predict
        if self.use_tflite:
            self.interpreter.set_tensor(self.input_details[0]['index'], img.numpy().astype(np.float32))
            self.interpreter.invoke()
            probs = self.interpreter.get_tensor(self.output_details[0]['index'])[0]
        else:
            probs = self.model.predict(img, verbose=0)[0]

        # Get top 2 indices
        top2_indices = np.argsort(probs)[::-1][:2]

        result = {
            'top1': {
                'class': self.class_names[top2_indices[0]],
                'confidence': float(probs[top2_indices[0]]),
                'rank': 1
            },
            'top2': {
                'class': self.class_names[top2_indices[1]],
                'confidence': float(probs[top2_indices[1]]),
                'rank': 2
            },
            'combined_confidence': float(probs[top2_indices[0]] + probs[top2_indices[1]])
        }

        if return_all:
            result['all_probabilities'] = {
                self.class_names[i]: float(probs[i])
                for i in range(len(self.class_names))
            }

        return result

    def format_for_api(self, image_path):
        """
        Format prediction for FastAPI response.

        Returns:
            dict: API-ready response format
        """
        result = self.predict_top2(image_path, return_all=True)

        return {
            'success': True,
            'predictions': [
                {
                    'plant_name': result['top1']['class'],
                    'confidence': round(result['top1']['confidence'] * 100, 2),
                    'rank': 1
                },
                {
                    'plant_name': result['top2']['class'],
                    'confidence': round(result['top2']['confidence'] * 100, 2),
                    'rank': 2
                }
            ],
            'combined_confidence': round(result['combined_confidence'] * 100, 2),
            'all_classes': {
                k: round(v * 100, 2)
                for k, v in result['all_probabilities'].items()
            }
        }

print("DrGreenPredictor class defined")
# Out:
# DrGreenPredictor class defined

# %%
# Demonstrate Top-2 predictions on validation images

# Initialize predictor with best model
predictor = DrGreenPredictor(f"{CONFIG['model_save_dir']}/best_model_v7.keras")

# Test on a few validation images
print("\n" + "="*60)
print("TOP-2 PREDICTION EXAMPLES")
print("="*60)

# Get sample images from each class
samples_per_class = 2
test_images = []

for i, class_name in enumerate(class_names):
    class_indices = np.where(val_labels == i)[0][:samples_per_class]
    for idx in class_indices:
        test_images.append((val_paths[idx], class_name))

# Show predictions
for img_path, true_class in test_images:
    result = predictor.predict_top2(img_path)

    top1 = result['top1']
    top2 = result['top2']

    # Check if correct in top 2
    correct_top1 = "CORRECT" if top1['class'] == true_class else ""
    correct_top2 = "CORRECT" if top2['class'] == true_class else ""
    in_top2 = top1['class'] == true_class or top2['class'] == true_class

    print(f"\nTrue: {true_class}")
    print(f"  1. {top1['class']}: {top1['confidence']*100:.1f}% {correct_top1}")
    print(f"  2. {top2['class']}: {top2['confidence']*100:.1f}% {correct_top2}")
    print(f"  In Top-2: {'YES' if in_top2 else 'NO'}")

print("\n" + "="*60)
# Out:
# DrGreenPredictor initialized with 4 classes
#
# ============================================================
# TOP-2 PREDICTION EXAMPLES
# ============================================================
#
# True: artemisia
#   1. artemisia: 38.5% CORRECT
#   2. carica: 37.5%
#   In Top-2: YES
#
# True: artemisia
#   1. kinkeliba: 29.8%
#   2. artemisia: 27.2% CORRECT
#   In Top-2: YES
#
# True: carica
#   1. carica: 48.7% CORRECT
#   2. goyavier: 35.7%
#   In Top-2: YES
#
# True: carica
#   1. carica: 45.1% CORRECT
#   2. goyavier: 28.8%
#   In Top-2: YES
#
# True: goyavier
#   1. goyavier: 38.6% CORRECT
#   2. kinkeliba: 28.6%
#   In Top-2: YES
#
# True: goyavier
#   1. goyavier: 59.0% CORRECT
#   2. carica: 24.4%
#   In Top-2: YES
#
# True: kinkeliba
#   1. carica: 39.1%
#   2. goyavier: 29.3%
#   In Top-2: NO
#
# True: kinkeliba
#   1. kinkeliba: 39.5% CORRECT
#   2. artemisia: 25.0%
#   In Top-2: YES
#
# ============================================================

# %%
# Show API response format

print("API Response Format Example:")
print("-" * 40)

# Get API format for one image
sample_path = val_paths[0]
api_response = predictor.format_for_api(sample_path)

import json
print(json.dumps(api_response, indent=2))

print("\n" + "="*60)
print("FASTAPI INTEGRATION")
print("="*60)

fastapi_code = '''
# FastAPI endpoint for Dr Green

from fastapi import FastAPI, UploadFile, File
from drgreen_predictor import DrGreenPredictor
import tempfile
import os

app = FastAPI()
predictor = DrGreenPredictor("models/drgreen_v7_stratified.tflite")

@app.post("/predict")
async def predict_plant(image: UploadFile = File(...)):
    """Identify plant from image with Top-2 predictions."""

    # Save uploaded file temporarily
    with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as tmp:
        content = await image.read()
        tmp.write(content)
        tmp_path = tmp.name

    try:
        # Get Top-2 predictions
        result = predictor.format_for_api(tmp_path)
        return result
    finally:
        os.unlink(tmp_path)
'''

print(fastapi_code)
# Out:
# API Response Format Example:
# ----------------------------------------
# {
#   "success": true,
#   "predictions": [
#     {
#       "plant_name": "carica",
#       "confidence": 48.65,
#       "rank": 1
#     },
#     {
#       "plant_name": "goyavier",
#       "confidence": 35.72,
#       "rank": 2
#     }
#   ],
#   "combined_confidence": 84.37,
#   "all_classes": {
#     "artemisia": 4.06,
#     "carica": 48.65,
#     "goyavier": 35.72,
#     "kinkeliba": 11.57
#   }
# }
#
# ============================================================
# FASTAPI INTEGRATION
# ============================================================
#
# # FastAPI endpoint for Dr Green
#
# from fastapi import FastAPI, UploadFile, File
# from drgreen_predictor import DrGreenPredictor
# import tempfile
# import os
#
# app = FastAPI()
# predictor = DrGreenPredictor("models/drgreen_v7_stratified.tflite")
#
# @app.post("/predict")
# async def predict_plant(image: UploadFile = File(...)):
#     """Identify plant from image with Top-2 predictions."""
#
#     # Save uploaded file temporarily
#     with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as tmp:
#         content = await image.read()
#         tmp.write(content)
#         tmp_path = tmp.name
#
#     try:
#         # Get Top-2 predictions
#         result = predictor.format_for_api(tmp_path)
#         return result
#     finally:
#         os.unlink(tmp_path)

# %% [markdown]
# ## 12. Download Models

# %%
from google.colab import files

print("Downloading models...")
files.download(keras_path)
files.download(tflite_path)
files.download(metadata_path)
print("Downloads initiated!")
# Out:
# Downloading models...
# Downloads initiated!
